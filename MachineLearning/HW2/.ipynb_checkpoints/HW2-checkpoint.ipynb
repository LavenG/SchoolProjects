# %% [markdown]
# # CSCI-UA 0473 - Introduction to Machine Learning
# ## HW 2 - Programming Assignment

# %% [markdown]
# ## Instructions
# For this programming assignment, an image (vector) was chosen and was passed through a weird function to obtain something mysterious (vector).
#
# You are given the mysterious vector and the weird function used to transform the original image.
#
# AND, YOUR TASK IS TO FIND THE ORIGINAL IMAGE.
#
# Hint: You will find Autograd helpful.

# %%
# %matplotlib inline

import matplotlib.pyplot as plot
import matplotlib.cm as cm

from autograd import numpy
from autograd import grad

from scipy import optimize
from scipy import spatial
import scipy

# %% [markdown]
# ## 1. Given

# %%
# The mysterious vector

import pickle    # Library used to save and load values of variables (Technically, it's called Serialization)

shp_original_img = (100, 100)  # Shape of the original image
#modified to fit python 3 settings 
mysterious_image = pickle.load(open('mysterious_image_t.p', 'rb'), encoding='latin1')# mysterious_image is a vector representing the morphed image
#plot.plot(mysterious_image)

reshaped = mysterious_image.reshape(100, 100)
plot.imshow(reshaped)

# %%
# The weird function which transformed the original image

def weird_function(x, n_iter=5):
    h = x    
    filt = numpy.array([-1./3, 1./3, -1./3])
    
    for ii in range(n_iter):
        h_l = numpy.concatenate([numpy.array([0]), h[:-1]])
        h_r = numpy.concatenate([h[1:], numpy.array([0])])
        h = filt[0] * h + filt[-1] * h_l + filt[1] * h_r
        
        if numpy.mod(ii, 2) == 0:
            h = numpy.concatenate([h[h.shape[0]//2:],h[:h.shape[0]//2]])
            
    return h

# %% [markdown]
# ## 2. Your Solution

# %%
# Your Code
random_image = numpy.random.rand(10000,)
print("random vector shape", random_image.shape)
print(random_image)
# Out:
# random vector shape (10000,)
# [ 0.03337812  0.70457798  0.19799485 ...,  0.08081406  0.93791773
#   0.70286492]

# %%
def mean_absolute_error(image, mysterious_image):
    prediction = weird_function(image)
    mae = numpy.mean(numpy.absolute(prediction - mysterious_image))
    grad_loss = grad(loss)
    return mae

def _loss(random_image, mysterious_image):
    return mean_absolute_error(random_image, mysterious_image),grad(loss)(random_image, mysterious_image)

# %%
scop = scipy.optimize.minimize(_loss, random_image, (mysterious_image), method='L-BFGS-B', jac=True)
plot.imshow(numpy.reshape(scop.x, (100,100)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-f92946a8f147> in <module>()
# ----> 1 scop = scipy.optimize.minimize(_loss, random_image, (mysterious_image), method='L-BFGS-B', jac=True)
#       2 plot.imshow(numpy.reshape(scop.x, (100,100)))
#
# /Users/alperenkaraoglu/anaconda/lib/python3.5/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     448     elif meth == 'l-bfgs-b':
#     449         return _minimize_lbfgsb(fun, x0, args, jac, bounds,
# --> 450                                 callback=callback, **options)
#     451     elif meth == 'tnc':
#     452         return _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#
# /Users/alperenkaraoglu/anaconda/lib/python3.5/site-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     326             # until the completion of the current minimization iteration.
#     327             # Overwrite f and g:
# --> 328             f, g = func_and_grad(x)
#     329         elif task_str.startswith(b'NEW_X'):
#     330             # new iteration
#
# /Users/alperenkaraoglu/anaconda/lib/python3.5/site-packages/scipy/optimize/lbfgsb.py in func_and_grad(x)
#     276     else:
#     277         def func_and_grad(x):
# --> 278             f = fun(x, *args)
#     279             g = jac(x, *args)
#     280             return f, g
#
# /Users/alperenkaraoglu/anaconda/lib/python3.5/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     290     def function_wrapper(*wrapper_args):
#     291         ncalls[0] += 1
# --> 292         return function(*(wrapper_args + args))
#     293
#     294     return ncalls, function_wrapper
#
# /Users/alperenkaraoglu/anaconda/lib/python3.5/site-packages/scipy/optimize/optimize.py in __call__(self, x, *args)
#      61     def __call__(self, x, *args):
#      62         self.x = numpy.asarray(x).copy()
# ---> 63         fg = self.fun(x, *args)
#      64         self.jac = fg[1]
#      65         return fg[0]
#
# <ipython-input-11-d62d0240f98b> in _loss(random_image, mysterious_image)
#       6
#       7 def _loss(random_image, mysterious_image):
# ----> 8     return mean_absolute_error(random_image, mysterious_image),grad(loss)(random_image, mysterious_image)
#
# <ipython-input-11-d62d0240f98b> in mean_absolute_error(image, mysterious_image)
#       2     prediction = weird_function(image)
#       3     mae = numpy.mean(numpy.absolute(prediction - mysterious_image))
# ----> 4     grad_loss = grad(loss)
#       5     return mae
#       6
#
# NameError: name 'loss' is not defined
